# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Using cached neo4j-5.26.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.11/site-packages (from neo4j) (2023.3.post1)
# Using cached neo4j-5.26.0-py3-none-any.whl (302 kB)
# Installing collected packages: neo4j
# Successfully installed neo4j-5.26.0

# %%
from neo4j import GraphDatabase, Driver, Result, Session
import configparser

# %%
config = configparser.ConfigParser()
config.read('./graph_api.config')

URI = "neo4j+s://hackatum-one.graphdatabase.ninja:443"
AUTH = (config.get('AUTH', 'username'), config.get('AUTH', 'password'))

drv: Driver = GraphDatabase.driver(uri=URI, auth=AUTH, max_connection_lifetime=60)
drv.database = "attendee14"
sess: Session = drv.session()
res: Result = sess.run(query="MATCH (n) RETURN n LIMIT 1")
print(res.single())
# Out:
# <Record n=<Node element_id='4:d0c5e6c7-6850-48df-9900-af21060ab9c0:0' labels=frozenset({'Hostname'}) properties={'label': 'humidifies.flickering.statuabamus.net', 'key': 'urn:dns:humidifies.flickering.statuabamus.net'}>>

# %%
from neo4j import GraphDatabase
import pandas as pd

def fetch_affected_software_inst(uri, auth, database, product, min_version, max_version):
    try:
        drv = GraphDatabase.driver(uri=uri, auth=auth, max_connection_lifetime=60)
        drv.database = database

        with drv.session() as sess:
            query = """
            MATCH (n:SoftwareInstallation)
            WHERE 
              (n.product CONTAINS $product AND n.version >= $min_version AND n.version <= $max_version)
            RETURN n
            """
            result = sess.run(query, product=product, min_version=min_version, max_version=max_version)

            # Fetch results into a list of dictionaries
            records = [record["n"] for record in result]

        # Convert to DataFrame for tabular display
        df = pd.DataFrame(records)
        print(df.to_string(index=False))  # Display table without index

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        drv.close()

# %%
# Docker Example
URI = "neo4j+s://hackatum-one.graphdatabase.ninja:443"
AUTH = ("attendee14", "EDUZB71$JF")
DATABASE = "attendee14"

fetch_affected_software_inst(
    uri=URI,
    auth=AUTH,
    database=DATABASE,
    product="Docker",
    min_version="23.0",
    max_version="26.1.3"
)
# Out:
#   edition                                       key       product publisher version
# Community cpe:/a:docker:docker_engine:24::community Docker Engine    Docker      24
# Community    cpe:/a:docker:docker_cli:24::community    Docker CLI    Docker      24

# %%
def count_affected_systems(uri, auth, database, product, min_version, max_version):
    try:
        drv = GraphDatabase.driver(uri=uri, auth=auth, max_connection_lifetime=60)
        drv.database = database

        with drv.session() as sess:
            query = """
            MATCH (n:SoftwareInstallation)
            WHERE 
              (n.product CONTAINS $product AND n.version >= $min_version AND n.version <= $max_version)
            MATCH (n)-[:related_software]-(system:System)
            RETURN COUNT(DISTINCT system) AS systemCount
            """
            result = sess.run(query, product=product, min_version=min_version, max_version=max_version)

            # Fetch the count from the result
            system_count = result.single()["systemCount"]
            print(f"Number of connected systems: {system_count}")

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        drv.close()

# %%
count_affected_systems(
    uri=URI,
    auth=AUTH,
    database=DATABASE,
    product="Docker",
    min_version="23.0",
    max_version="26.1.3"
)
# Out:
# Number of connected systems: 202

# %%
def fetch_affected_systems(uri, auth, database, product, min_version, max_version):
    try:
        drv = GraphDatabase.driver(uri=uri, auth=auth, max_connection_lifetime=60)
        drv.database = database

        with drv.session() as sess:
            query = """
            MATCH (n:SoftwareInstallation)
            WHERE 
              (n.product CONTAINS $product AND n.version >= $min_version AND n.version <= $max_version)
            MATCH (n)-[:related_software]-(system:System)
            RETURN DISTINCT system
            """
            result = sess.run(query, product=product, min_version=min_version, max_version=max_version)

            records = [record["system"] for record in result]

        if records:
            df = pd.DataFrame(records)
            print(df.to_string(index=False))
        else:
            print("No affected systems found.")

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        drv.close()

# %%
fetch_affected_systems(
    uri=URI,
    auth=AUTH,
    database=DATABASE,
    product="Docker",
    min_version="23.0",
    max_version="26.1.3"
)
# Out:
#  critical        id                  key  provider_name        state        sub_type    type
#         1 266540047 urn:system:266540047       Homebrew       Active           Other Unknown
#         0 266495165 urn:system:266495165       Homebrew       Active           Other  Server
#         0 266467486 urn:system:266467486       Homebrew       Active  Virtual Server  Server
#         1 266611090 urn:system:266611090       Homebrew       Active           Other Unknown
#         0 266668102 urn:system:266668102       Homebrew       Active           Other  Server
#         1 266778190 urn:system:266778190        Helheim Inconsistent  Virtual Server  Server
#         0 266693977 urn:system:266693977  MagnaCumLaude       Active           Other Unknown
#         0 266693976 urn:system:266693976  MagnaCumLaude       Active           Other Unknown
#         0 266958572 urn:system:266958572       Homebrew Inconsistent           Other  Server
#         1 266485431 urn:system:266485431       Homebrew       Active           Other Unknown
#         1 266485435 urn:system:266485435       Homebrew       Active           Other Unknown
#         1 266485434 urn:system:266485434       Homebrew       Active           Other Unknown
#         1 266485433 urn:system:266485433       Homebrew       Active           Other Unknown
#         1 266485432 urn:system:266485432       Homebrew       Active           Other Unknown
#         0 266727917 urn:system:266727917       Homebrew       Active  Virtual Server  Server
#         1 266569620 urn:system:266569620       Homebrew       Active           Other Unknown
#         0 266726279 urn:system:266726279       Homebrew       Active           Other Unknown
#         1 266448623 urn:system:266448623       Homebrew       Active           Other Unknown
#         0 266653871 urn:system:266653871       Homebrew       Active           Other  Server
#         1 266885150 urn:system:266885150       Homebrew       Active           Other Unknown
#         1 266795880 urn:system:266795880       Homebrew       Active           Other Unknown
#         1 267138632 urn:system:267138632       Homebrew       Active           Other Unknown
#         0 267138633 urn:system:267138633       Homebrew       Active           Other Unknown
#         1 267138634 urn:system:267138634       Homebrew       Active           Other Unknown
#         0 266802927 urn:system:266802927       Homebrew       Active           Other Unknown
#         0 266824606 urn:system:266824606       Homebrew Inconsistent           Other  Server
#         0 267057000 urn:system:267057000       Homebrew       Active  Virtual Server  Server
#         1 267022350 urn:system:267022350       Homebrew       Active           Other Unknown
#         1 267138637 urn:system:267138637       Homebrew       Active           Other Unknown
#         1 267138636 urn:system:267138636       Homebrew       Active           Other Unknown
#         1 267138635 urn:system:267138635       Homebrew       Active           Other Unknown
#         0 267261790 urn:system:267261790       Homebrew       Active  Virtual Server  Server
#         1 267138638 urn:system:267138638       Homebrew       Active           Other Unknown
#         0 267888249 urn:system:267888249       Homebrew       Active           Other  Server
#         0 267298488 urn:system:267298488       Homebrew       Active           Other Unknown
#         0 267903338 urn:system:267903338       Homebrew       Active           Other  Server
#         0 267904432 urn:system:267904432       Homebrew       Active           Other  Server
#         1 267319736 urn:system:267319736        Helheim Inconsistent  Virtual Server  Server
#         1 267214189 urn:system:267214189       Homebrew       Active           Other Unknown
#         1 267214188 urn:system:267214188       Homebrew       Active           Other Unknown
#         1 267946496 urn:system:267946496       Homebrew       Active           Other Unknown
#         1 267917904 urn:system:267917904       Homebrew       Active           Other Unknown
#         0 267908026 urn:system:267908026       Homebrew       Active           Other  Server
#         1 267971176 urn:system:267971176       Homebrew       Active           Other Unknown
#         1 267946497 urn:system:267946497       Homebrew       Active           Other Unknown
#         1 268163744 urn:system:268163744       Homebrew       Active           Other Unknown
#         1 268163772 urn:system:268163772       Homebrew       Active           Other Unknown
#         0 267907741 urn:system:267907741       Homebrew       Active           Other  Server
#         0 267907742 urn:system:267907742       Homebrew       Active           Other Unknown
#         0 268068238 urn:system:268068238       Homebrew       Active  Virtual Server  Server
#         0 268127623 urn:system:268127623       Homebrew       Active           Other  Server
#         0 267908028 urn:system:267908028       Homebrew       Active           Other  Server
#         0 268195915 urn:system:268195915       Homebrew       Active           Other Unknown
#         0 268087731 urn:system:268087731       Homebrew       Active           Other Unknown
#         0 268087622 urn:system:268087622       Homebrew       Active  Virtual Server  Server
#         0 264474639 urn:system:264474639        Helheim       Active  Virtual Server  Server
#         1 268226190 urn:system:268226190       Homebrew       Active           Other Unknown
#         1 268136380 urn:system:268136380       Homebrew       Active           Other  Server
#         0 264453071 urn:system:264453071       Homebrew       Active  Virtual Server  Server
#         1 268154639 urn:system:268154639        Helheim       Active  Virtual Server  Server
#         1 268221288 urn:system:268221288       Homebrew       Active           Other Unknown
#         0 268197478 urn:system:268197478       Homebrew       Active           Other Unknown
#         0 268197096 urn:system:268197096       Homebrew       Active           Other Unknown
#         1 264531856 urn:system:264531856       Homebrew       Active           Other Unknown
#         1 264732272 urn:system:264732272 Advanced Nerds       Active           Other  Server
#         1 264452253 urn:system:264452253 Advanced Nerds       Active           Other  Server
#         1 268203971 urn:system:268203971       Homebrew       Active           Other Unknown
#         0 268228521 urn:system:268228521       Homebrew       Active           Other  Server
#         1 264455846 urn:system:264455846       Homebrew       Active           Other Unknown
#         1 265277134 urn:system:265277134       Homebrew       Active           Other Unknown
#         1 264532178 urn:system:264532178       Homebrew       Active           Other Unknown
#         0 264766092 urn:system:264766092      Celestial       Active  Virtual Server  Server
#         1 264766093 urn:system:264766093      Celestial       Active  Virtual Server  Server
#         0 264766094 urn:system:264766094      Celestial       Active           Other Unknown
#         1 264768277 urn:system:264768277       Homebrew       Active           Other Unknown
#         0 265852378 urn:system:265852378        Helheim       Active  Virtual Server  Server
#         0 265852377 urn:system:265852377        Helheim       Active  Virtual Server  Server
#         1 264806768 urn:system:264806768       Homebrew       Active           Other Unknown
#         1 265277135 urn:system:265277135       Homebrew       Active           Other Unknown
#         1 265306295 urn:system:265306295       Homebrew       Active           Other Unknown
#         1 265918973 urn:system:265918973       Homebrew       Active           Other Unknown
#         1 265918972 urn:system:265918972       Homebrew       Active           Other Unknown
#         0 265852092 urn:system:265852092       Homebrew       Active           Other Unknown
#         0 265852094 urn:system:265852094       Homebrew       Active           Other Unknown
#         0 265852123 urn:system:265852123       Homebrew       Active           Other  Server
#         1 264806769 urn:system:264806769       Homebrew       Active           Other Unknown
#         1 266030469 urn:system:266030469       Homebrew       Active           Other Unknown
#         1 265875355 urn:system:265875355       Homebrew       Active           Other Unknown
#         0 266011069 urn:system:266011069       Homebrew       Active           Other  Server
#         1 266010059 urn:system:266010059       Homebrew       Active           Other  Server
#         0 265334198 urn:system:265334198        Helheim Inconsistent  Virtual Server  Server
#         0 265865058 urn:system:265865058        Helheim       Active           Other  Server
#         1 266005729 urn:system:266005729       Homebrew       Active  Virtual Server  Server
#         1 257275919 urn:system:257275919       Homebrew       Active           Other Unknown
#         0 266331183 urn:system:266331183       Homebrew       Active           Other Unknown
#         1 259067014 urn:system:259067014       Homebrew       Active           Other Unknown
#         1 263036045 urn:system:263036045       Homebrew       Active           Other Unknown
#         0 262714445 urn:system:262714445       Homebrew       Active           Other Unknown
#         0 256045266 urn:system:256045266        Helheim       Active  Virtual Server  Server
#         1 257160290 urn:system:257160290       Homebrew       Active           Other Unknown
#         1 257160291 urn:system:257160291       Homebrew       Active           Other Unknown
#         0 257157873 urn:system:257157873       Homebrew       Active           Other Unknown
#         1 257129712 urn:system:257129712       Homebrew       Active           Other Unknown
#         1 257130003 urn:system:257130003       Homebrew       Active           Other  Server
#         0 257119886 urn:system:257119886       Homebrew Inconsistent  Virtual Server  Server
#         1 256630967 urn:system:256630967       Homebrew       Active           Other  Server
#         0 257139444 urn:system:257139444       Homebrew       Active           Other  Server
#         0 257117383 urn:system:257117383       Homebrew       Active  Virtual Server  Server
#         1 257230101 urn:system:257230101       Homebrew       Active           Other Unknown
#         1 257248619 urn:system:257248619        Helheim Inconsistent  Virtual Server  Server
#         0 257467917 urn:system:257467917       Homebrew       Active           Other  Server
#         1 257334389 urn:system:257334389        Helheim       Active  Virtual Server  Server
#         1 257195121 urn:system:257195121       Homebrew       Active           Other Unknown
#         1 257334368 urn:system:257334368        Helheim       Active  Virtual Server  Server
#         1 257660503 urn:system:257660503       Homebrew       Active           Other Unknown
#         1 257660504 urn:system:257660504       Homebrew       Active           Other Unknown
#         0 257799231 urn:system:257799231       Homebrew       Active           Other Unknown
#         1 254424828 urn:system:254424828       Homebrew       Active           Other  Server
#         0 254143205 urn:system:254143205  MagnaCumLaude       Active           Other  Server
#         1 257756144 urn:system:257756144       Homebrew       Active Computer Device  Client
#         0 257796138 urn:system:257796138       Homebrew Inconsistent           Other  Server
#         0 253957285 urn:system:253957285       Homebrew       Active Computer Device  Client
#         0 254207575 urn:system:254207575       Homebrew       Active           Other  Server
#         1 257756129 urn:system:257756129       Homebrew Inconsistent Computer Device  Client
#         0 257696491 urn:system:257696491       Homebrew Inconsistent           Other  Server
#         1 254231297 urn:system:254231297       Homebrew       Active           Other Unknown
#         0 254137683 urn:system:254137683       Homebrew       Active  Virtual Server  Server
#         0 254137682 urn:system:254137682       Homebrew       Active  Virtual Server  Server
#         0 254426100 urn:system:254426100       Homebrew       Active           Other  Server
#         0 255091551 urn:system:255091551       Homebrew       Active           Other  Server
#         1 254257831 urn:system:254257831       Homebrew       Active           Other  Server
#         1 254429558 urn:system:254429558 Advanced Nerds       Active           Other  Server
#         1 254037115 urn:system:254037115       Homebrew       Active           Other Unknown
#         1 255074723 urn:system:255074723       Homebrew       Active  Virtual Server  Server
#         0 254995250 urn:system:254995250       Homebrew       Active Computer Device  Client
#         1 255074729 urn:system:255074729       Homebrew       Active  Virtual Server  Server
#         1 255121519 urn:system:255121519       Homebrew       Active  Virtual Server  Server
#         1 255145995 urn:system:255145995       Homebrew       Active           Other  Server
#         1 255146480 urn:system:255146480       Homebrew       Active           Other  Server
#         1 255145997 urn:system:255145997       Homebrew       Active           Other  Server
#         1 255145998 urn:system:255145998       Homebrew       Active           Other  Server
#         0 255211107 urn:system:255211107       Homebrew       Active  Virtual Server  Server
#         1 255145993 urn:system:255145993       Homebrew       Active           Other  Server
#         0 251752804 urn:system:251752804       Homebrew       Active           Other  Server
#         0 251761852 urn:system:251761852       Homebrew       Active Computer Device  Client
#         0 251761843 urn:system:251761843       Homebrew       Active           Other  Server
#         1 255052847 urn:system:255052847       Homebrew       Active           Other  Server
#         0 251761849 urn:system:251761849       Homebrew       Active Computer Device  Client
#         1 255121518 urn:system:255121518       Homebrew       Active  Virtual Server  Server
#         1 255121516 urn:system:255121516       Homebrew       Active  Virtual Server  Server
#         0 255786463 urn:system:255786463  MagnaCumLaude       Active           Other  Server
#         1 255145992 urn:system:255145992       Homebrew       Active           Other  Server
#         0 251762971 urn:system:251762971       Homebrew       Active           Other  Server
#         0 252806397 urn:system:252806397       Homebrew       Active           Other Unknown
#         0 251738462 urn:system:251738462       Homebrew       Active           Other  Server
#         0 251738433 urn:system:251738433       Homebrew       Active           Other  Server
#         0 255271494 urn:system:255271494 Advanced Nerds       Active           Other  Server
#         0 251761853 urn:system:251761853       Homebrew       Active Computer Device  Client
#         0 251761851 urn:system:251761851       Homebrew       Active Computer Device  Client
#         0 255303542 urn:system:255303542       Homebrew       Active           Other  Server
#         0 252752184 urn:system:252752184       Homebrew       Active           Other Unknown
#         0 251739120 urn:system:251739120       Homebrew       Active           Other Unknown
#         0 251733458 urn:system:251733458       Homebrew Inconsistent           Other  Server
#         0 251761932 urn:system:251761932       Homebrew       Active           Other  Server
#         0 251761933 urn:system:251761933       Homebrew       Active Computer Device  Client
#         0 253303959 urn:system:253303959       Homebrew Inconsistent           Other  Server
#         0 253303960 urn:system:253303960       Homebrew       Active           Other  Server
#         0 253303523 urn:system:253303523       Homebrew       Active           Other  Server
#         0 253303062 urn:system:253303062       Homebrew Inconsistent           Other  Server
#         0 253278799 urn:system:253278799       Homebrew       Active  Virtual Server  Server
#         1 241240326 urn:system:241240326       Homebrew       Active           Other Unknown
#         0 241371809 urn:system:241371809        Helheim       Active  Virtual Server  Server
#         0 241197186 urn:system:241197186       Bastille       Active           Other  Server
#         1 241240324 urn:system:241240324       Homebrew       Active           Other Unknown
#         0 241925931 urn:system:241925931        Helheim       Active  Virtual Server  Server
#         1 241396503 urn:system:241396503       Homebrew       Active           Other  Server
#         1 241396504 urn:system:241396504       Homebrew       Active           Other  Server
#         1 241240323 urn:system:241240323       Homebrew       Active           Other Unknown
#         1 241424848 urn:system:241424848       Homebrew       Active           Other Unknown
#         0 241619075 urn:system:241619075       Homebrew       Active           Other Unknown
#         1 241424849 urn:system:241424849       Homebrew       Active           Other Unknown
#         1 241424850 urn:system:241424850       Homebrew       Active           Other Unknown
#         1 241240325 urn:system:241240325       Homebrew       Active           Other Unknown
#         1 241790221 urn:system:241790221       Homebrew       Active           Other  Server
#         1 241489467 urn:system:241489467       Homebrew Inconsistent Computer Device  Client
#         0 241884633 urn:system:241884633        Helheim       Active  Virtual Server  Server
#         1 241466117 urn:system:241466117       Homebrew       Active           Other Unknown
#         0 242135349 urn:system:242135349        Helheim       Active  Virtual Server  Server
#         1 241855638 urn:system:241855638       Homebrew       Active           Other Unknown
#         1 241881141 urn:system:241881141       Bastille       Active           Other  Server
#         1 241925085 urn:system:241925085        Helheim       Active  Virtual Server  Server
#         1 241925367 urn:system:241925367        Helheim       Active  Virtual Server  Server
#         1 241923548 urn:system:241923548        Helheim       Active  Virtual Server  Server
#         1 242137602 urn:system:242137602        Helheim       Active  Virtual Server  Server
#         0 241942842 urn:system:241942842       Homebrew       Active           Other  Server
#         1 242159325 urn:system:242159325       Homebrew       Active           Other Unknown
#         0 242222723 urn:system:242222723 Advanced Nerds       Active           Other  Server
#         0 242225745 urn:system:242225745        Helheim       Active  Virtual Server  Server
#         0 242216533 urn:system:242216533        Helheim       Active  Virtual Server  Server
#         1 242222105 urn:system:242222105       Homebrew       Active           Other Unknown
#         0 264431872 urn:system:264431872       Homebrew       Active           Other Unknown
#         0 256158945 urn:system:256158945       Homebrew       Active     log. Server  Server

# %%
def find_responsible_person(uri, auth, database, product, min_version, max_version):
    try:
        drv = GraphDatabase.driver(uri=uri, auth=auth, max_connection_lifetime=60)
        drv.database = database

        with drv.session() as sess:
            query = """
            MATCH (n:SoftwareInstallation)
            WHERE 
              (n.product CONTAINS $product AND n.version >= $min_version AND n.version <= $max_version)
            MATCH (n)-[:related_software]-(system:System)
            MATCH (system)-[:runs_on]-(app:Application)
            MATCH (app)-[:owned_by]-(org:OrgUnit)
            MATCH (org)-[:head_of]-(person:Person)
            RETURN DISTINCT system, person, org, app
            """
            result = sess.run(query, product=product, min_version=min_version, max_version=max_version)

            records = [{"system": record["system"], "person": record.get("person", None), 
                        "application": record.get("app", None), "org_unit": record.get("org", None)} 
                       for record in result]

        responsible_data = []
        for record in records:
            system_id = record["system"].id if record["system"] else None
            person_name = record["person"].get("fullname") if record["person"] else "No responsible person"
            app_name = record["application"].get("name") if record["application"] else "No application"
            org_name = record["org_unit"].get("orgCode") if record["org_unit"] else "No org unit"
            
            responsible_data.append({
                "System ID": system_id,
                "Application": app_name,
                #"Org Unit": org_name,
                "Responsible Person": person_name
            })

        df = pd.DataFrame(responsible_data)
        print(df.to_string(index=False))

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
     Antique white Lisbon Iraida Sigurbjörnsdóttir
#    8446642                     Antique white Lisbon         Sarasati Baquero
#    8446642                     Antique white Lisbon          Krisztián Bonsu
#    3716535                      Ruddy pink Belgrade         Akouvi Sepulveda
#    3716534                      Ruddy pink Belgrade         Akouvi Sepulveda
#    8667851             Tangerine yellow Ouagadougou           Brett Nakayama
#    8623490             Tangerine yellow Ouagadougou           Brett Nakayama
#    8623489             Tangerine yellow Ouagadougou           Brett Nakayama
#    8623488             Tangerine yellow Ouagadougou           Brett Nakayama
#    8667849             Tangerine yellow Ouagadougou           Brett Nakayama
#    8506683             Tangerine yellow Ouagadougou           Brett Nakayama
#    3869772                      Baby blue Abu Dhabi    Koami Thorvaldsdottir
#    8474490                     Antique white Lisbon Iraida Sigurbjörnsdóttir
#    8474490                     Antique white Lisbon         Sarasati Baquero
#    8474490                     Antique white Lisbon          Krisztián Bonsu
#    8610652             Tangerine yellow Ouagadougou           Brett Nakayama
#    3923103                     Antique white Lisbon Iraida Sigurbjörnsdóttir
#    3923103                     Antique white Lisbon         Sarasati Baquero
#    3923103                     Antique white Lisbon          Krisztián Bonsu
#    8479842             Tangerine yellow Ouagadougou           Brett Nakayama
#    3794515                Alizarin crimson Castries           Brett Nakayama
#    8446649                   Laurel green Port Vila              Miksa Bonsu
#    8446646                   Laurel green Port Vila              Miksa Bonsu
#    8446655                   Laurel green Port Vila              Miksa Bonsu
#    8435448                   Laurel green Port Vila              Miksa Bonsu
#    8424966             Tangerine yellow Ouagadougou           Brett Nakayama
#    8397733                     Antique white Lisbon Iraida Sigurbjörnsdóttir
#    8397733                     Antique white Lisbon         Sarasati Baquero
#    8397733                     Antique white Lisbon          Krisztián Bonsu
#    8397739                     Antique white Lisbon Iraida Sigurbjörnsdóttir
#    8397739                     Antique white Lisbon         Sarasati Baquero
#    8397739                     Antique white Lisbon          Krisztián Bonsu
#    8397619             Tangerine yellow Ouagadougou           Brett Nakayama
#    3890332                     Egyptian blue Moscow            Manoj Baffour
# /var/folders/w_/0j5zvgc122d9lh7r90c5xg540000gn/T/ipykernel_16296/3521279229.py:25: DeprecationWarning: `id` is deprecated, use `element_id` instead
#   system_id = record["system"].id if record["system"] else None

# %%
def try_fetch_epss(uri, auth, database, cve_id):
    try:
        drv = GraphDatabase.driver(uri=uri, auth=auth, max_connection_lifetime=60)
        drv.database = database

        with drv.session() as sess:
            query = """
            MATCH (cve:Vulnerability)
            WHERE cve.cve = $cve_id
            MATCH (cve)-[:has_rating]->(rating:EPSS)
            RETURN cve.cve AS CVE_ID, rating.score AS EPSS_Score
            """
            result = sess.run(query, cve_id=cve_id)
            
            records = [record for record in result]
            if not records:
                print(f"{cve_id} not found in the database.")
                return None

            df = pd.DataFrame(records, columns=["CVE_ID", "EPSS_Score"])
            return df

    except Exception as e:
        print(f"An error occurred: {e}")
        return None
    finally:
        drv.close()

# %%
cve_data = try_fetch_epss(uri=URI, auth=AUTH, database=DATABASE, cve_id="CVE-2019-8033")
if cve_data is not None:
    print(cve_data)
# Out:
#           CVE_ID  EPSS_Score
# 0  CVE-2019-8033     0.01393
